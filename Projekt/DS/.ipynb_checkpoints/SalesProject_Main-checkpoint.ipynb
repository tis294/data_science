# %% [markdown]
# # DataScientest - SalesData Project
# Last updated: 2023-06-23 13:19:27

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#DataScientest---SalesData-Project" data-toc-modified-id="DataScientest---SalesData-Project-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>DataScientest - SalesData Project</a></span><ul class="toc-item"><li><span><a href="#Data-import-&amp;-first-analysis" data-toc-modified-id="Data-import-&amp;-first-analysis-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Data import &amp; first analysis</a></span><ul class="toc-item"><li><span><a href="#Import-of-all-neccesarry-modules" data-toc-modified-id="Import-of-all-neccesarry-modules-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Import of all neccesarry modules</a></span></li><li><span><a href="#Import-of-df-and-first-informations" data-toc-modified-id="Import-of-df-and-first-informations-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Import of df and first informations</a></span></li><li><span><a href="#Column-Informations:" data-toc-modified-id="Column-Informations:-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Column Informations:</a></span></li><li><span><a href="#Description-of-numerical-columns:" data-toc-modified-id="Description-of-numerical-columns:-1.1.4"><span class="toc-item-num">1.1.4&nbsp;&nbsp;</span>Description of numerical columns:</a></span></li><li><span><a href="#Handling-NaN-Values" data-toc-modified-id="Handling-NaN-Values-1.1.5"><span class="toc-item-num">1.1.5&nbsp;&nbsp;</span>Handling NaN-Values</a></span><ul class="toc-item"><li><span><a href="#NaN-Evaluation" data-toc-modified-id="NaN-Evaluation-1.1.5.1"><span class="toc-item-num">1.1.5.1&nbsp;&nbsp;</span>NaN Evaluation</a></span></li><li><span><a href="#Grouping-Countries-to-Regions" data-toc-modified-id="Grouping-Countries-to-Regions-1.1.5.2"><span class="toc-item-num">1.1.5.2&nbsp;&nbsp;</span>Grouping Countries to Regions</a></span></li><li><span><a href="#Replacing-NaN-Values-for-Nation-&amp;-PremiumCountry" data-toc-modified-id="Replacing-NaN-Values-for-Nation-&amp;-PremiumCountry-1.1.5.3"><span class="toc-item-num">1.1.5.3&nbsp;&nbsp;</span>Replacing NaN Values for Nation &amp; PremiumCountry</a></span></li></ul></li><li><span><a href="#show-new-df" data-toc-modified-id="show-new-df-1.1.6"><span class="toc-item-num">1.1.6&nbsp;&nbsp;</span>show new df</a></span></li></ul></li><li><span><a href="#Still-ToDo" data-toc-modified-id="Still-ToDo-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Still ToDo</a></span><ul class="toc-item"><li><span><a href="#Check-premiumDuration" data-toc-modified-id="Check-premiumDuration-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Check premiumDuration</a></span><ul class="toc-item"><li><span><a href="#make-some-tests-on-date-columns" data-toc-modified-id="make-some-tests-on-date-columns-1.2.1.1"><span class="toc-item-num">1.2.1.1&nbsp;&nbsp;</span>make some tests on date columns</a></span></li></ul></li><li><span><a href="#Check-behaviour-of-status_code-values" data-toc-modified-id="Check-behaviour-of-status_code-values-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Check behaviour of status_code values</a></span><ul class="toc-item"><li><span><a href="#Example-lines" data-toc-modified-id="Example-lines-1.2.2.1"><span class="toc-item-num">1.2.2.1&nbsp;&nbsp;</span>Example lines</a></span></li><li><span><a href="#filter-&amp;-drop-column" data-toc-modified-id="filter-&amp;-drop-column-1.2.2.2"><span class="toc-item-num">1.2.2.2&nbsp;&nbsp;</span>filter &amp; drop column</a></span></li></ul></li><li><span><a href="#Check-behaviour-of-other-columns" data-toc-modified-id="Check-behaviour-of-other-columns-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Check behaviour of other columns</a></span><ul class="toc-item"><li><span><a href="#Deductible,-CmpPrivate,-Model,-Zone,-product_group" data-toc-modified-id="Deductible,-CmpPrivate,-Model,-Zone,-product_group-1.2.3.1"><span class="toc-item-num">1.2.3.1&nbsp;&nbsp;</span>Deductible, CmpPrivate, Model, Zone, product_group</a></span></li></ul></li><li><span><a href="#Group-Data" data-toc-modified-id="Group-Data-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>Group Data</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ## Data import & first analysis

# %% [markdown]
# ### Import of all neccesarry modules

# %%
# Append new Modules here:    
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Import of df and first informations

# %% [markdown]
# Further descriptions of the columns and rows can be found in __[SalesData-Description.xlsx](https://bdae0-my.sharepoint.com/:x:/r/personal/jonathan_leipold_bdae-gruppe_de/Documents/DataScientest/Sales-Project/SalesData-Description.xlsx?d=wc46862516c97407cbb63550cda70df39&csf=1&web=1&e=HffTcl)__

# %%
#import df. set encoding to 'latin-1' necassary to fit to csv-file
df = pd.read_csv('SalesDate-Example.csv',encoding='latin-1')

pd.set_option('display.max_columns', None) #allow display of all columns
df.head()
# Out:
#   Indicator status_code status_name   BirthDate Nation  AgeAtPremium  \
# 0         P           P     Bezahlt  1956-03-12     DE            62
# 1         P           P     Bezahlt  1956-03-12     DE            62
# 2         P           P     Bezahlt  1956-03-12     DE            62
# 3         P           S   Storniert  1979-08-25     DE            39
# 4         P           P     Bezahlt  1986-02-04     FR            32
#
#    PolicyAgeAtPremium premium_startDate premium_endDate policy_StartDate  \
# 0                   1        2018-08-01      2018-08-31       2017-08-01
# 1                   1        2018-10-01      2018-10-31       2017-08-01
# 2                   1        2018-11-01      2018-11-30       2017-08-01
# 3                   2        2018-11-01      2018-11-30       2016-11-01
# 4                   1        2018-03-01      2018-03-31       2016-05-01
#
#   policy_EffEndDate  premiumAmount  FeeAmount feeRate ContractID  \
# 0        2019-07-31           47.0       18.8     40%     p16174
# 1        2019-07-31           83.0       33.2     40%     p16174
# 2        2019-07-31           47.0       18.8     40%     p16174
# 3        2018-01-31           83.0       33.2     40%     p13934
# 4        2018-12-31           83.0       33.2     40%     p12569
#
#    product_code MainProductCode MainProductName  Deductible CmpPrivate  Model  \
# 0  Q055.003.000            G007        Product6         0.0          I   1001
# 1  Q055.001.000            G007        Product6         0.0          I   1001
# 2  Q055.003.000            G007        Product6         0.0          I   1001
# 3  Q055.001.000            G007        Product6         0.0          I   1001
# 4  Q055.001.000            G007        Product6         0.0          I   1001
#
#    Zone        ZoneDesc premium_Country premium_CountryName  product_group  \
# 0  1002  Ohne USA / CAN              NP               Nepal            102
# 1  1002  Ohne USA / CAN              NP               Nepal            100
# 2  1002  Ohne USA / CAN              NP               Nepal            102
# 3  1002  Ohne USA / CAN              CN               China            100
# 4  1002  Ohne USA / CAN              SG           Singapore            100
#
#       product_groupName
# 0  Zusatzversicherungen
# 1              Produkte
# 2  Zusatzversicherungen
# 3              Produkte
# 4              Produkte

# %% [markdown]
# ### Column Informations:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230010 entries, 0 to 230009
# Data columns (total 27 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Indicator            230010 non-null  object
#  1   status_code          230010 non-null  object
#  2   status_name          230010 non-null  object
#  3   BirthDate            230010 non-null  object
#  4   Nation               228444 non-null  object
#  5   AgeAtPremium         230010 non-null  int64
#  6   PolicyAgeAtPremium   230010 non-null  int64
#  7   premium_startDate    230010 non-null  object
#  8   premium_endDate      230010 non-null  object
#  9   policy_StartDate     230010 non-null  object
#  10  policy_EffEndDate    230010 non-null  object
#  11  premiumAmount        230010 non-null  float64
#  12  FeeAmount            230010 non-null  float64
#  13  feeRate              229984 non-null  object
#  14  ContractID           230010 non-null  object
#  15  product_code         230010 non-null  object
#  16  MainProductCode      230010 non-null  object
#  17  MainProductName      230010 non-null  object
#  18  Deductible           230010 non-null  float64
#  19  CmpPrivate           230010 non-null  object
#  20  Model                230010 non-null  int64
#  21  Zone                 230010 non-null  int64
#  22  ZoneDesc             229984 non-null  object
#  23  premium_Country      227432 non-null  object
#  24  premium_CountryName  227945 non-null  object
#  25  product_group        230010 non-null  int64
#  26  product_groupName    230010 non-null  object
# dtypes: float64(3), int64(5), object(19)
# memory usage: 47.4+ MB

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Observation:</b>date columns have dtype 'object' --> change to datetime
# </div>
#
# - Therefore we wrote a function called 'convert_columns_to_datetime' and put it into the 'helpers.py' file in the same notebook
# - This way the main notebook stays more clear
# - Other helpers functions will follow

# %%
from helpers import convert_columns_to_datetime
#help(convert_columns_to_datetime) #Description of the function -> uncomment, if needed

# %%
columns_to_convert = ['BirthDate','premium_startDate', 'premium_endDate', 'policy_StartDate', 'policy_EffEndDate']

df = convert_columns_to_datetime(df, columns_to_convert)
print(df.dtypes)
df.head()
# Out:
# Indicator                      object
# status_code                    object
# status_name                    object
# BirthDate              datetime64[ns]
# Nation                         object
# AgeAtPremium                    int64
# PolicyAgeAtPremium              int64
# premium_startDate      datetime64[ns]
# premium_endDate        datetime64[ns]
# policy_StartDate       datetime64[ns]
# policy_EffEndDate      datetime64[ns]
# premiumAmount                 float64
# FeeAmount                     float64
# feeRate                        object
# ContractID                     object
# product_code                   object
# MainProductCode                object
# MainProductName                object
# Deductible                    float64
# CmpPrivate                     object
# Model                           int64
# Zone                            int64
# ZoneDesc                       object
# premium_Country                object
# premium_CountryName            object
# product_group                   int64
# product_groupName              object
# dtype: object
#   Indicator status_code status_name  BirthDate Nation  AgeAtPremium  \
# 0         P           P     Bezahlt 1956-03-12     DE            62
# 1         P           P     Bezahlt 1956-03-12     DE            62
# 2         P           P     Bezahlt 1956-03-12     DE            62
# 3         P           S   Storniert 1979-08-25     DE            39
# 4         P           P     Bezahlt 1986-02-04     FR            32
#
#    PolicyAgeAtPremium premium_startDate premium_endDate policy_StartDate  \
# 0                   1        2018-08-01      2018-08-31       2017-08-01
# 1                   1        2018-10-01      2018-10-31       2017-08-01
# 2                   1        2018-11-01      2018-11-30       2017-08-01
# 3                   2        2018-11-01      2018-11-30       2016-11-01
# 4                   1        2018-03-01      2018-03-31       2016-05-01
#
#   policy_EffEndDate  premiumAmount  FeeAmount feeRate ContractID  \
# 0        2019-07-31           47.0       18.8     40%     p16174
# 1        2019-07-31           83.0       33.2     40%     p16174
# 2        2019-07-31           47.0       18.8     40%     p16174
# 3        2018-01-31           83.0       33.2     40%     p13934
# 4        2018-12-31           83.0       33.2     40%     p12569
#
#    product_code MainProductCode MainProductName  Deductible CmpPrivate  Model  \
# 0  Q055.003.000            G007        Product6         0.0          I   1001
# 1  Q055.001.000            G007        Product6         0.0          I   1001
# 2  Q055.003.000            G007        Product6         0.0          I   1001
# 3  Q055.001.000            G007        Product6         0.0          I   1001
# 4  Q055.001.000            G007        Product6         0.0          I   1001
#
#    Zone        ZoneDesc premium_Country premium_CountryName  product_group  \
# 0  1002  Ohne USA / CAN              NP               Nepal            102
# 1  1002  Ohne USA / CAN              NP               Nepal            100
# 2  1002  Ohne USA / CAN              NP               Nepal            102
# 3  1002  Ohne USA / CAN              CN               China            100
# 4  1002  Ohne USA / CAN              SG           Singapore            100
#
#       product_groupName
# 0  Zusatzversicherungen
# 1              Produkte
# 2  Zusatzversicherungen
# 3              Produkte
# 4              Produkte

# %% [markdown]
# ### Description of numerical columns:

# %%
df.describe()
# Out:
#                            BirthDate   AgeAtPremium  PolicyAgeAtPremium  \
# count                         230010  230010.000000       230010.000000
# mean   1979-02-12 01:35:16.426242336      39.724521            1.104213
# min              1948-01-10 00:00:00      -1.000000           -1.000000
# 25%              1967-04-05 00:00:00      30.000000            0.000000
# 50%              1979-04-04 00:00:00      39.000000            1.000000
# 75%              1988-11-09 00:00:00      52.000000            2.000000
# max              2023-01-25 00:00:00      66.000000            4.000000
# std                              NaN      14.845829            1.273986
#
#                    premium_startDate                premium_endDate  \
# count                         230010                         230010
# mean   2019-05-04 19:14:29.503065088  2019-06-03 05:31:40.435632896
# min              2014-11-01 00:00:00            2014-11-30 00:00:00
# 25%              2017-04-01 00:00:00            2017-04-30 00:00:00
# 50%              2019-05-01 00:00:00            2019-05-31 00:00:00
# 75%              2021-07-01 00:00:00            2021-07-31 00:00:00
# max              2023-12-01 00:00:00            2023-12-31 00:00:00
# std                              NaN                            NaN
#
#                     policy_StartDate              policy_EffEndDate  \
# count                         230010                         230010
# mean   2017-10-14 11:12:15.025433856  2021-01-12 01:24:42.728577024
# min              2013-03-01 00:00:00            2014-07-31 00:00:00
# 25%              2015-08-01 00:00:00            2018-08-31 00:00:00
# 50%              2017-08-13 12:00:00            2020-10-31 00:00:00
# 75%              2020-01-01 00:00:00            2023-01-31 00:00:00
# max              2023-08-30 00:00:00            2028-07-31 00:00:00
# std                              NaN                            NaN
#
#        premiumAmount      FeeAmount  Deductible          Model           Zone  \
# count  230010.000000  230010.000000    230010.0  230010.000000  230010.000000
# mean       69.794634      27.769139         0.0    1003.744094    1005.093796
# min      -425.000000    -165.750000         0.0    1001.000000      -1.000000
# 25%        79.000000      31.600000         0.0    1001.000000    1002.000000
# 50%        83.000000      33.200000         0.0    1001.000000    1004.000000
# 75%        88.000000      35.200000         0.0    1008.000000    1009.000000
# max       425.000000     165.750000         0.0    1008.000000    1010.000000
# std        61.198797      24.342121         0.0       3.417405      11.147499
#
#        product_group
# count  230010.000000
# mean      100.088692
# min       100.000000
# 25%       100.000000
# 50%       100.000000
# 75%       100.000000
# max       102.000000
# std         0.411726

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Observation:</b> Deductible has only value 0 (this is due to the fact, that we only look at one product and that this product offers only deuctible = 0).
# </div>

# %% [markdown]
# ### Handling NaN-Values

# %% [markdown]
# #### NaN Evaluation

# %% [markdown]
# columns with NaN-values: Nation (= Nationality), Premium_Country(Name), feeRate
# --> check Nation & Country first

# %%
#Nation
df['Nation'].value_counts(dropna=False)
NaN_Nations = df['Nation'].isna().sum()/len(df)
print('Part of NaN-values in Nation column = {:.1%}'.format(NaN_Nations))

#have a look on rows with NaN Nations
df[df['Nation'].isna() == True]
# Out:
# Part of NaN-values in Nation column = 0.7%
#        Indicator status_code status_name  BirthDate Nation  AgeAtPremium  \
# 346            P           P     Bezahlt 1963-04-16    NaN            54
# 347            P           P     Bezahlt 1963-04-16    NaN            55
# 348            P           P     Bezahlt 1963-04-16    NaN            55
# 985            P           P     Bezahlt 1978-04-04    NaN            40
# 1035           P           P     Bezahlt 1978-04-04    NaN            40
# ...          ...         ...         ...        ...    ...           ...
# 228190         P           P     Bezahlt 1959-01-07    NaN            63
# 228546         P           P     Bezahlt 1961-06-15    NaN            59
# 228547         P           P     Bezahlt 1961-06-15    NaN            60
# 228548         P           P     Bezahlt 1961-06-15    NaN            60
# 229507         P           P     Bezahlt 1959-01-07    NaN            63
#
#         PolicyAgeAtPremium premium_startDate premium_endDate policy_StartDate  \
# 346                      3        2018-02-01      2018-02-28       2014-10-01
# 347                      3        2018-05-01      2018-05-31       2014-10-01
# 348                      3        2018-08-01      2018-08-31       2014-10-01
# 985                      0        2018-12-01      2018-12-31       2018-02-01
# 1035                     0        2018-10-01      2018-10-31       2018-02-01
# ...                    ...               ...             ...              ...
# 228190                   0        2022-05-01      2022-05-31       2022-01-01
# 228546                   0        2021-04-01      2021-04-30       2020-11-01
# 228547                   0        2021-07-01      2021-07-31       2020-11-01
# 228548                   0        2021-10-01      2021-10-31       2020-11-01
# 229507                   0        2022-04-01      2022-04-30       2022-01-01
#
#        policy_EffEndDate  premiumAmount  FeeAmount feeRate ContractID  \
# 346           2019-09-30           83.0      33.20     40%      p7599
# 347           2019-09-30           83.0      33.20     40%      p7599
# 348           2019-09-30           83.0      33.20     40%      p7599
# 985           2020-05-31           79.0      31.60     40%     p16831
# 1035          2020-05-31           79.0      31.60     40%     p16831
# ...                  ...            ...        ...     ...        ...
# 228190        2022-05-31          -97.0     -37.83     39%     p29844
# 228546        2025-10-31           88.0      35.20     40%     p25935
# 228547        2025-10-31           88.0      35.20     40%     p25935
# 228548        2025-10-31           88.0      35.20     40%     p25935
# 229507        2022-05-31          -97.0     -37.83     39%     p29844
#
#         product_code MainProductCode MainProductName  Deductible CmpPrivate  \
# 346     Q055.001.000            G007        Product6         0.0          I
# 347     Q055.001.000            G007        Product6         0.0          I
# 348     Q055.001.000            G007        Product6         0.0          I
# 985     Q055.001.000            G007        Product6         0.0          I
# 1035    Q055.001.000            G007        Product6         0.0          I
# ...              ...             ...             ...         ...        ...
# 228190  Q055.006.000            G007        Product6         0.0          I
# 228546  Q055.006.000            G007        Product6         0.0          I
# 228547  Q055.006.000            G007        Product6         0.0          I
# 228548  Q055.006.000            G007        Product6         0.0          I
# 229507  Q055.006.000            G007        Product6         0.0          I
#
#         Model  Zone             ZoneDesc premium_Country premium_CountryName  \
# 346      1001  1002       Ohne USA / CAN              ES               Spain
# 347      1001  1002       Ohne USA / CAN              ES               Spain
# 348      1001  1002       Ohne USA / CAN              ES               Spain
# 985      1001  1004          Deutschland              DE             Germany
# 1035     1001  1004          Deutschland              DE             Germany
# ...       ...   ...                  ...             ...                 ...
# 228190   1008  1009  Ohne USA / CAN / CH              BR              Brazil
# 228546   1008  1009  Ohne USA / CAN / CH              TH            Thailand
# 228547   1008  1009  Ohne USA / CAN / CH              TH            Thailand
# 228548   1008  1009  Ohne USA / CAN / CH              TH            Thailand
# 229507   1008  1009  Ohne USA / CAN / CH              BR              Brazil
#
#         product_group product_groupName
# 346               100          Produkte
# 347               100          Produkte
# 348               100          Produkte
# 985               100          Produkte
# 1035              100          Produkte
# ...               ...               ...
# 228190            100          Produkte
# 228546            100          Produkte
# 228547            100          Produkte
# 228548            100          Produkte
# 229507            100          Produkte
#
# [1566 rows x 27 columns]

# %% [markdown]
# **Idea:** Built function to further analyse rows with NaN values in specific input column and run on columns above
# 1. Output: Compare to the rest of df by graphs to might recognize similarities (premium Country / policy_StartDate / CmpPrivate / ...)
# 2. if not: Set to dummie value 'XX' to keep rest of rows informations

# %%
#Import Function from helpers.py
from helpers import NaN_col_info
#help(NaN_col_info) #uncomment for disctiption, if neccesarry

# %%
#NaN_col_info(df, 'Nation','premium_startDate')
NaN_col_info(df, 'Nation','policy_StartDate')
#NaN_col_info(df, 'Nation','premiumAmount')
NaN_col_info(df, 'Nation','premium_Country')

# %% [markdown]
# Alternative function to plot both distributions in 1 plot, one for each input columns

# %%
from helpers import plot_distributions

# %%
#example
nan_col = 'Nation'
comp_cols = ['premium_Country','policy_StartDate']  # Add other columns as needed
#plot_distributions(df, nan_col, comp_cols)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Observation:</b>
# <ul>
#     <li>Missing value in Nation column are more likely in recent policies / premiums.</li>
#     <li>Distribution of premium Country is different for NaN-Nations, but too many countries for comparison. </li>
# </ul>
# </div>

# %% [markdown]
# #### Grouping Countries to Regions

# %% [markdown]
# A closer look on relplot betwwen nation & premiumCountry is difficult due to too many countries. <br>
# As well too many values for discriptive column to later create dummy-values for modelling.
#
# <div class="alert alert-block alert-warning">
# <b>Therefore: Create Clusters of Regions and map the countries to it's regions.</b><br>
# (Special Features: 'DE' as seperate region (because most commmon) and 'XX' (because = unknown))
# </div>
#
# import 2 functions to get unique country names and map them to their corresponding region

# %%
from helpers import get_unique_values, generate_country_region_mapping

# %% [markdown]
# 1. get unqiue countries

# %%
unique_countries = get_unique_values(df, columns=['Nation', 'premium_Country'])

# %% [markdown]
# 2. map regions

# %%
country_mapping = generate_country_region_mapping(unique_countries)
print("Country to Region Mapping of DE:", country_mapping['DE']) #test
# Out:
# Country to Region Mapping of DE: DE

# %% [markdown]
# 3. create new columns in df

# %%
df['Nation_region'] = df['Nation'].map(country_mapping)
print(df[['Nation','Nation_region']]['Nation_region'].value_counts(dropna=False),'\n')

df['premiumCountry_region'] = df['premium_Country'].map(country_mapping)
print(df[['premium_Country','premiumCountry_region']]['premiumCountry_region'].value_counts(dropna=False))
# Out:
# Nation_region
# DE          140291
# Europe       71580
# Asia          7888
# Americas      6278
# NaN           1566
# Africa        1363
# Oceania       1044
# Name: count, dtype: int64
#
# premiumCountry_region
# Asia        82486
# DE          53383
# Europe      40693
# Americas    26552
# Africa      15626
# Oceania      7832
# NaN          2724
# XX            712
# Polar           2
# Name: count, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Idea: Set NaN to 'XX' in both colums.
# </div>

# %% [markdown]
# #### Replacing NaN Values for Nation & PremiumCountry

# %%
#fill NaN values with 'XX'
df[['Nation','Nation_region','premium_Country','premiumCountry_region']] = df[['Nation','Nation_region','premium_Country','premiumCountry_region']].fillna('XX')

#check result
print(df[['Nation','Nation_region']]['Nation_region'].value_counts(dropna=False),'\n')
print(df[['premium_Country','premiumCountry_region']]['premiumCountry_region'].value_counts(dropna=False))
# Out:
# Nation_region
# DE          140291
# Europe       71580
# Asia          7888
# Americas      6278
# XX            1566
# Africa        1363
# Oceania       1044
# Name: count, dtype: int64
#
# premiumCountry_region
# Asia        82486
# DE          53383
# Europe      40693
# Americas    26552
# Africa      15626
# Oceania      7832
# XX           3436
# Polar           2
# Name: count, dtype: int64

# %% [markdown]
# ### show new df

# %%
df.head()
# Out:
#   Indicator status_code status_name  BirthDate Nation  AgeAtPremium  \
# 0         P           P     Bezahlt 1956-03-12     DE            62
# 1         P           P     Bezahlt 1956-03-12     DE            62
# 2         P           P     Bezahlt 1956-03-12     DE            62
# 3         P           S   Storniert 1979-08-25     DE            39
# 4         P           P     Bezahlt 1986-02-04     FR            32
#
#    PolicyAgeAtPremium premium_startDate premium_endDate policy_StartDate  \
# 0                   1        2018-08-01      2018-08-31       2017-08-01
# 1                   1        2018-10-01      2018-10-31       2017-08-01
# 2                   1        2018-11-01      2018-11-30       2017-08-01
# 3                   2        2018-11-01      2018-11-30       2016-11-01
# 4                   1        2018-03-01      2018-03-31       2016-05-01
#
#   policy_EffEndDate  premiumAmount  FeeAmount feeRate ContractID  \
# 0        2019-07-31           47.0       18.8     40%     p16174
# 1        2019-07-31           83.0       33.2     40%     p16174
# 2        2019-07-31           47.0       18.8     40%     p16174
# 3        2018-01-31           83.0       33.2     40%     p13934
# 4        2018-12-31           83.0       33.2     40%     p12569
#
#    product_code MainProductCode MainProductName  Deductible CmpPrivate  Model  \
# 0  Q055.003.000            G007        Product6         0.0          I   1001
# 1  Q055.001.000            G007        Product6         0.0          I   1001
# 2  Q055.003.000            G007        Product6         0.0          I   1001
# 3  Q055.001.000            G007        Product6         0.0          I   1001
# 4  Q055.001.000            G007        Product6         0.0          I   1001
#
#    Zone        ZoneDesc premium_Country premium_CountryName  product_group  \
# 0  1002  Ohne USA / CAN              NP               Nepal            102
# 1  1002  Ohne USA / CAN              NP               Nepal            100
# 2  1002  Ohne USA / CAN              NP               Nepal            102
# 3  1002  Ohne USA / CAN              CN               China            100
# 4  1002  Ohne USA / CAN              SG           Singapore            100
#
#       product_groupName Nation_region premiumCountry_region
# 0  Zusatzversicherungen            DE                  Asia
# 1              Produkte            DE                  Asia
# 2  Zusatzversicherungen            DE                  Asia
# 3              Produkte            DE                  Asia
# 4              Produkte        Europe                  Asia

# %% [markdown]
# ## Still ToDo

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Main preprocessing goal:</b> Create df where rows are crouped by months.<br>
#      Therefore we need:
# <ol>
#     <li><div>
#         <input type="checkbox" id="month" name="month" checked>
#         <label for="month">a "Month" column with YYYY-MM</label>
#     </div></li>
#     <li><div>
#         <input type="checkbox" id="target" name="target" unchecked>
#         <label for="target">create our <b> target value(s):</b> sum premiumAmmount, count ContractID </label>
#     </div></li>
#         <li><div>
#         <input type="checkbox" id="columns" name="columns" unchecked>
#         <label for="columns">to decide what to do with other columns</label>
#     </div></li>
# </ol>
# </div>

# %% [markdown]
# ### Check premiumDuration

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Next Step for understanding:</b> premiumStart & -End always in the same month? --> check duration of premium Payments
# <ol>
# <li> create column with premiumDuration = premium_endDate-premium_StartDate </li>
# <li> value_counts of new premiumDuration </li>
# </ol>
#
# Then find out how rows can be grouped by month.
# </div>

# %% [markdown]
# #### make some tests on date columns

# %%
#check, if premiumStart is always the first of a month
df.premium_startDate.dt.day.value_counts(normalize=True) #--> yes
# Out:
# premium_startDate
# 1    1.0
# Name: proportion, dtype: float64

# %%
#comparison: premium_endDate distribution
df.premium_endDate.dt.day.value_counts(normalize=True).round(3)
# Out:
# premium_endDate
# 31    0.578
# 30    0.341
# 28    0.062
# 29    0.018
# 1     0.000
# 15    0.000
# 10    0.000
# 27    0.000
# 24    0.000
# 22    0.000
# 20    0.000
# 21    0.000
# 8     0.000
# 2     0.000
# 26    0.000
# 16    0.000
# 23    0.000
# 3     0.000
# 19    0.000
# 17    0.000
# 18    0.000
# 9     0.000
# 25    0.000
# 6     0.000
# 12    0.000
# Name: proportion, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Observation:</b> premium_startDate always 1. of month, premium_endDate almost always (~99,9%)
# </div>

# %%
#check premiumDuration in months
print('premiumDurations in months:\n',((df.premium_endDate.dt.month - df.premium_startDate.dt.month)+1).value_counts()) #--> always 1 month
print('\n(in other words:) parts with premium_endDate in same month as premium_startDate:\n',(df.premium_endDate.dt.month == df.premium_startDate.dt.month).value_counts(normalize=True))
# Out:
# premiumDurations in months:
#  1    230010
# Name: count, dtype: int64
#
# (in other words:) parts with premium_endDate in same month as premium_startDate:
#  True    1.0
# Name: proportion, dtype: float64

# %% [markdown]
# Create column with **premiumMonth** (without day)

# %%
df['premiumMonth'] = df.premium_startDate.dt.to_period('M')
df[['premium_startDate','premium_endDate', 'premiumMonth']].head(10)
# Out:
#   premium_startDate premium_endDate premiumMonth
# 0        2018-08-01      2018-08-31      2018-08
# 1        2018-10-01      2018-10-31      2018-10
# 2        2018-11-01      2018-11-30      2018-11
# 3        2018-11-01      2018-11-30      2018-11
# 4        2018-03-01      2018-03-31      2018-03
# 5        2018-06-01      2018-06-30      2018-06
# 6        2018-09-01      2018-09-30      2018-09
# 7        2018-05-01      2018-05-31      2018-05
# 8        2018-08-01      2018-08-31      2018-08
# 9        2018-11-01      2018-11-30      2018-11

# %% [markdown]
# ### Check behaviour of status_code values

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <ol>
#     <li> Get first overview over distribution of column. </li>
#     <li> Take Example ContractIDs with 'status_code' = 'S' and see how it behaves compared to 'P'. </li>
#     <li> Decide how to handle it when grouping premiums. </li>
# </ol>
# </div>

# %%
#Distribution of column
df.status_name.value_counts(normalize=True).round(3)*100
# Out:
# status_name
# Bezahlt      85.2
# Storniert    14.4
# Offen         0.5
# Name: proportion, dtype: float64

# %% [markdown]
# ~15% "Storniert" --> closer look on example lines

# %% [markdown]
# #### Example lines

# %%
pd.options.display.max_rows = None #show all rows

# %%
# take example of contractID with minimum one row with Status "S"
df.loc[df.ContractID == 'p13934'][['premiumMonth', 'status_code', 'premiumAmount']].sort_values('premiumMonth')
# Out:
#        premiumMonth status_code  premiumAmount
# 13156       2016-11           P           79.0
# 116261      2016-12           P           79.0
# 138141      2017-01           P           79.0
# 138334      2017-02           P           79.0
# 137991      2017-03           P           79.0
# 138142      2017-04           P           79.0
# 138335      2017-05           P           79.0
# 133544      2017-06           P           79.0
# 138143      2017-07           P           79.0
# 138336      2017-08           P           79.0
# 133545      2017-09           P           79.0
# 141508      2017-10           P           79.0
# 138337      2017-11           P           79.0
# 133546      2017-12           P           79.0
# 51121       2018-01           P           83.0
# 166576      2018-02           S           83.0
# 48761       2018-02           S          -83.0
# 93788       2018-03           S           83.0
# 58855       2018-03           S          -83.0
# 97212       2018-04           S          -83.0
# 165520      2018-04           S           83.0
# 172711      2018-05           S          -83.0
# 166577      2018-05           S           83.0
# 58856       2018-06           S          -83.0
# 93789       2018-06           S           83.0
# 162366      2018-07           S           83.0
# 97213       2018-07           S          -83.0
# 172712      2018-08           S          -83.0
# 167973      2018-08           S           83.0
# 93791       2018-09           S           83.0
# 170696      2018-09           S          -83.0
# 162367      2018-10           S           83.0
# 99009       2018-10           S          -83.0
# 3           2018-11           S           83.0
# 172713      2018-11           S          -83.0
# 93792       2018-12           S           83.0
# 96916       2018-12           S          -83.0

# %%
# group and sum for example contractID
df.loc[df.ContractID == 'p13934'][['premiumMonth', 'status_code', 'premiumAmount']].groupby(['status_code']).sum('premiumAmount')
# Out:
#              premiumAmount
# status_code
# P                   1189.0
# S                      0.0

# %% [markdown]
#  <div class="alert alert-block alert-info">
# <b>Observation:</b> rows with status_code "S" seem to balance each other out on 0. Doublecheck on whole df..
# </div>

# %%
#premiumSum per status
df_S = df[['premiumMonth', 'status_code', 'premiumAmount']].groupby(['status_code']).sum('premiumAmount')
df_S
# Out:
#              premiumAmount
# status_code
# O                101316.00
# P              15930895.00
# S                 21252.85

# %% [markdown]
#  <div class="alert alert-block alert-info">
# <b>Observation:</b> Not all cancelled payments (status_code = 'S') balance each other out to 0.
# </div>

# %% [markdown]
# **Overview over percentage of premiumAmount sum per status**

# %%
(df_S/df_S.sum()).round(4)*100
# Out:
#              premiumAmount
# status_code
# O                     0.63
# P                    99.24
# S                     0.13

# %% [markdown]
#  <div class="alert alert-block alert-info">
# <b>Observation:</b> Compared to percentage of rows (~15%) of status 'S' their sum of premiumAmount is low (~0.1%). Must mainly adds up to/around 0.
# </div>

# %% [markdown]
# Only small percentage of cancelled payments --> altough closer look on specific contractIDs with special premiumAmounts for status 'S'

# %%
#get contractIDs with max/min sum of premiumAmount for cancelled payments
df.loc[df.status_code == 'S'][['ContractID','premiumMonth', 'status_code', 'premiumAmount']].groupby(['ContractID','status_code']).sum('premiumAmount').sort_values('premiumAmount', ascending=False)
# Out:
#                         premiumAmount
# ContractID status_code
# p9728      S             2.449000e+03
# p17222     S             1.869000e+03
# p8074      S             9.960000e+02
# p17070     S             9.960000e+02
# p10337     S             9.480000e+02
# p10336     S             9.480000e+02
# p12829     S             8.650000e+02
# p23897     S             8.500000e+02
# p18197     S             7.900000e+02
# p16080     S             7.650000e+02
# p16250     S             7.110000e+02
# p11656     S             7.110000e+02
# p11657     S             7.110000e+02
# p14908     S             5.890000e+02
# p14907     S             5.890000e+02
# p12910     S             5.400000e+02
# p16387     S             4.150000e+02
# p20380     S             3.900000e+02
# p11371     S             3.830000e+02
# p9096      S             3.720000e+02
# p18187     S             2.700000e+02
# p23710     S             2.550000e+02
# p14679     S             2.490000e+02
# p20953     S             2.490000e+02
# p5872      S             2.480000e+02
# p6402      S             2.480000e+02
# p7491      S             2.370000e+02
# p13948     S             2.370000e+02
# p4960      S             2.370000e+02
# p17096     S             1.660000e+02
# p4905      S             1.580000e+02
# p4856      S             1.580000e+02
# p18537     S             1.580000e+02
# p4855      S             1.580000e+02
# p4504      S             1.580000e+02
# p4163      S             1.580000e+02
# p5601      S             1.580000e+02
# p4505      S             1.580000e+02
# p6306      S             1.580000e+02
# p6184      S             1.580000e+02
# p6305      S             1.580000e+02
# p7001      S             1.580000e+02
# p6153      S             1.580000e+02
# p22173     S             8.300000e+01
# p11362     S             8.300000e+01
# p11370     S             8.300000e+01
# p16284     S             7.900000e+01
# p7699      S             7.900000e+01
# p15119     S             7.900000e+01
# p7823      S             7.900000e+01
# p14035     S             7.900000e+01
# p7641      S             7.900000e+01
# p18258     S             7.900000e+01
# p12216     S             7.900000e+01
# p6042      S             7.900000e+01
# p11883     S             7.900000e+01
# p10701     S             7.900000e+01
# p8311      S             7.900000e+01
# p15847     S             7.900000e+01
# p15621     S             7.900000e+01
# p4257      S             7.900000e+01
# p13461     S             7.900000e+01
# p13369     S             7.900000e+01
# p11783     S             7.900000e+01
# p9978      S             7.900000e+01
# p10124     S             7.900000e+01
# p7385      S             1.421085e-14
# p11252     S             2.664535e-15
# p25283     S             0.000000e+00
# p28594     S             0.000000e+00
# p25112     S             0.000000e+00
# p25113     S             0.000000e+00
# p25114     S             0.000000e+00
# p25120     S             0.000000e+00
# p25122     S             0.000000e+00
# p25158     S             0.000000e+00
# p25181     S             0.000000e+00
# p25235     S             0.000000e+00
# p25261     S             0.000000e+00
# p25269     S             0.000000e+00
# p28583     S             0.000000e+00
# p25111     S             0.000000e+00
# p28573     S             0.000000e+00
# p25290     S             0.000000e+00
# p25304     S             0.000000e+00
# p25309     S             0.000000e+00
# p25334     S             0.000000e+00
# p25335     S             0.000000e+00
# p25336     S             0.000000e+00
# p25337     S             0.000000e+00
# p8561      S             0.000000e+00
# p8564      S             0.000000e+00
# p8566      S             0.000000e+00
# p8569      S             0.000000e+00
# p8570      S             0.000000e+00
# p8571      S             0.000000e+00
# p8572      S             0.000000e+00
# p8574      S             0.000000e+00
# p8494      S             0.000000e+00
# p8475      S             0.000000e+00
# p8577      S             0.000000e+00
# p8435      S             0.000000e+00
# p8386      S             0.000000e+00
# p8387      S             0.000000e+00
# p8388      S             0.000000e+00
# p8393      S             0.000000e+00
# p8395      S             0.000000e+00
# p8398      S             0.000000e+00
# p8400      S             0.000000e+00
# p8402      S             0.000000e+00
# p8405      S             0.000000e+00
# p8415      S             0.000000e+00
# p8417      S             0.000000e+00
# p8430      S             0.000000e+00
# p8438      S             0.000000e+00
# p8474      S             0.000000e+00
# p8449      S             0.000000e+00
# p8451      S             0.000000e+00
# p8453      S             0.000000e+00
# p8462      S             0.000000e+00
# p8463      S             0.000000e+00
# p8464      S             0.000000e+00
# p8467      S             0.000000e+00
# p8469      S             0.000000e+00
# p8470      S             0.000000e+00
# p8471      S             0.000000e+00
# p8472      S             0.000000e+00
# p8473      S             0.000000e+00
# p8575      S             0.000000e+00
# p8578      S             0.000000e+00
# p8377      S             0.000000e+00
# p8730      S             0.000000e+00
# p8679      S             0.000000e+00
# p8680      S             0.000000e+00
# p8682      S             0.000000e+00
# p8688      S             0.000000e+00
# p8689      S             0.000000e+00
# p8692      S             0.000000e+00
# p8705      S             0.000000e+00
# p8707      S             0.000000e+00
# p8710      S             0.000000e+00
# p8717      S             0.000000e+00
# p8724      S             0.000000e+00
# p8728      S             0.000000e+00
# p8731      S             0.000000e+00
# p8672      S             0.000000e+00
# p8735      S             0.000000e+00
# p8737      S             0.000000e+00
# p8738      S             0.000000e+00
# p8740      S             0.000000e+00
# p8742      S             0.000000e+00
# p8743      S             0.000000e+00
# p8747      S             0.000000e+00
# p8750      S             0.000000e+00
# p8751      S             0.000000e+00
# p8761      S             0.000000e+00
# p8762      S             0.000000e+00
# p8768      S             0.000000e+00
# p8676      S             0.000000e+00
# p8670      S             0.000000e+00
# p8582      S             0.000000e+00
# p8633      S             0.000000e+00
# p8585      S             0.000000e+00
# p8586      S             0.000000e+00
# p8587      S             0.000000e+00
# p8588      S             0.000000e+00
# p8589      S             0.000000e+00
# p8590      S             0.000000e+00
# p8598      S             0.000000e+00
# p8600      S             0.000000e+00
# p8608      S             0.000000e+00
# p8621      S             0.000000e+00
# p8623      S             0.000000e+00
# p8626      S             0.000000e+00
# p8635      S             0.000000e+00
# p8667      S             0.000000e+00
# p8636      S             0.000000e+00
# p8639      S             0.000000e+00
# p8641      S             0.000000e+00
# p8642      S             0.000000e+00
# p8643      S             0.000000e+00
# p8646      S             0.000000e+00
# p8649      S             0.000000e+00
# p8653      S             0.000000e+00
# p8654      S             0.000000e+00
# p8655      S             0.000000e+00
# p8658      S             0.000000e+00
# p8659      S             0.000000e+00
# p8385      S             0.000000e+00
# p8374      S             0.000000e+00
# p28818     S             0.000000e+00
# p8023      S             0.000000e+00
# p7965      S             0.000000e+00
# p7966      S             0.000000e+00
# p8192      S             0.000000e+00
# p8195      S             0.000000e+00
# p8198      S             0.000000e+00
# p8201      S             0.000000e+00
# p8205      S             0.000000e+00
# p8206      S             0.000000e+00
# p8208      S             0.000000e+00
# p8210      S             0.000000e+00
# p8212      S             0.000000e+00
# p8213      S             0.000000e+00
# p8228      S             0.000000e+00
# p8771      S             0.000000e+00
# p8773      S             0.000000e+00
# p8776      S             0.000000e+00
# p9550      S             0.000000e+00
# p9490      S             0.000000e+00
# p9491      S             0.000000e+00
# p9494      S             0.000000e+00
# p9495      S             0.000000e+00
# p9496      S             0.000000e+00
# p9499      S             0.000000e+00
# p9500      S             0.000000e+00
# p9504      S             0.000000e+00
# p9518      S             0.000000e+00
# p9522      S             0.000000e+00
# p9525      S             0.000000e+00
# p9539      S             0.000000e+00
# p9556      S             0.000000e+00
# p9454      S             0.000000e+00
# p9562      S             0.000000e+00
# p9565      S             0.000000e+00
# p9572      S             0.000000e+00
# ...
# p15490     S             0.000000e+00
# p15500     S             0.000000e+00
# p15506     S             0.000000e+00
# p15511     S             0.000000e+00
# p15512     S             0.000000e+00
# p15517     S             0.000000e+00
# p15521     S             0.000000e+00
# p15523     S             0.000000e+00
# p15525     S             0.000000e+00
# p15530     S             0.000000e+00
# p15378     S             0.000000e+00
# p15532     S             0.000000e+00
# p15536     S             0.000000e+00
# p15541     S             0.000000e+00
# p15543     S             0.000000e+00
# p15552     S             0.000000e+00
# p15556     S             0.000000e+00
# p15564     S             0.000000e+00
# p15565     S             0.000000e+00
# p16681     S             0.000000e+00
# p15569     S             0.000000e+00
# p15570     S             0.000000e+00
# p15576     S             0.000000e+00
# p15481     S             0.000000e+00
# p15474     S             0.000000e+00
# p15473     S             0.000000e+00
# p15472     S             0.000000e+00
# p15379     S             0.000000e+00
# p15380     S             0.000000e+00
# p15382     S             0.000000e+00
# p15397     S             0.000000e+00
# p15398     S             0.000000e+00
# p15412     S             0.000000e+00
# p15413     S             0.000000e+00
# p15421     S             0.000000e+00
# p15423     S             0.000000e+00
# p15428     S             0.000000e+00
# p15436     S             0.000000e+00
# p15437     S             0.000000e+00
# p15438     S             0.000000e+00
# p15439     S             0.000000e+00
# p15440     S             0.000000e+00
# p15445     S             0.000000e+00
# p15450     S             0.000000e+00
# p15451     S             0.000000e+00
# p15454     S             0.000000e+00
# p15459     S             0.000000e+00
# p15462     S             0.000000e+00
# p15466     S             0.000000e+00
# p15467     S             0.000000e+00
# p15468     S             0.000000e+00
# p15469     S             0.000000e+00
# p15085     S             0.000000e+00
# p15083     S             0.000000e+00
# p15598     S             0.000000e+00
# p14810     S             0.000000e+00
# p14763     S             0.000000e+00
# p14767     S             0.000000e+00
# p14772     S             0.000000e+00
# p14773     S             0.000000e+00
# p14774     S             0.000000e+00
# p14778     S             0.000000e+00
# p14779     S             0.000000e+00
# p14780     S             0.000000e+00
# p14781     S             0.000000e+00
# p14793     S             0.000000e+00
# p14795     S             0.000000e+00
# p14797     S             0.000000e+00
# p14816     S             0.000000e+00
# p14752     S             0.000000e+00
# p14817     S             0.000000e+00
# p14818     S             0.000000e+00
# p14829     S             0.000000e+00
# p14830     S             0.000000e+00
# p14837     S             0.000000e+00
# p14839     S             0.000000e+00
# p14841     S             0.000000e+00
# p14845     S             0.000000e+00
# p14852     S             0.000000e+00
# p14857     S             0.000000e+00
# p14858     S             0.000000e+00
# p14859     S             0.000000e+00
# p14760     S             0.000000e+00
# p14751     S             0.000000e+00
# p15082     S             0.000000e+00
# p14645     S             0.000000e+00
# p14570     S             0.000000e+00
# p14573     S             0.000000e+00
# p14578     S             0.000000e+00
# p14582     S             0.000000e+00
# p14583     S             0.000000e+00
# p14601     S             0.000000e+00
# p14606     S             0.000000e+00
# p14608     S             0.000000e+00
# p14622     S             0.000000e+00
# p14631     S             0.000000e+00
# p14634     S             0.000000e+00
# p14639     S             0.000000e+00
# p14657     S             0.000000e+00
# p14744     S             0.000000e+00
# p14665     S             0.000000e+00
# p14667     S             0.000000e+00
# p14678     S             0.000000e+00
# p14703     S             0.000000e+00
# p14711     S             0.000000e+00
# p14712     S             0.000000e+00
# p14713     S             0.000000e+00
# p14718     S             0.000000e+00
# p14727     S             0.000000e+00
# p14728     S             0.000000e+00
# p14729     S             0.000000e+00
# p14730     S             0.000000e+00
# p14867     S             0.000000e+00
# p14870     S             0.000000e+00
# p14873     S             0.000000e+00
# p15029     S             0.000000e+00
# p14983     S             0.000000e+00
# p14984     S             0.000000e+00
# p14985     S             0.000000e+00
# p14986     S             0.000000e+00
# p14987     S             0.000000e+00
# p14996     S             0.000000e+00
# p14998     S             0.000000e+00
# p15005     S             0.000000e+00
# p15007     S             0.000000e+00
# p15018     S             0.000000e+00
# p15026     S             0.000000e+00
# p15027     S             0.000000e+00
# p15033     S             0.000000e+00
# p14885     S             0.000000e+00
# p15036     S             0.000000e+00
# p15037     S             0.000000e+00
# p15038     S             0.000000e+00
# p15058     S             0.000000e+00
# p15059     S             0.000000e+00
# p15068     S             0.000000e+00
# p15069     S             0.000000e+00
# p15070     S             0.000000e+00
# p15072     S             0.000000e+00
# p15074     S             0.000000e+00
# p15075     S             0.000000e+00
# p15081     S             0.000000e+00
# p14982     S             0.000000e+00
# p14981     S             0.000000e+00
# p14972     S             0.000000e+00
# p14964     S             0.000000e+00
# p14886     S             0.000000e+00
# p14889     S             0.000000e+00
# p14893     S             0.000000e+00
# p14894     S             0.000000e+00
# p14898     S             0.000000e+00
# p14899     S             0.000000e+00
# p14903     S             0.000000e+00
# p14904     S             0.000000e+00
# p14905     S             0.000000e+00
# p14911     S             0.000000e+00
# p14913     S             0.000000e+00
# p14914     S             0.000000e+00
# p14915     S             0.000000e+00
# p14916     S             0.000000e+00
# p14917     S             0.000000e+00
# p14922     S             0.000000e+00
# p14942     S             0.000000e+00
# p14946     S             0.000000e+00
# p14947     S             0.000000e+00
# p14949     S             0.000000e+00
# p14955     S             0.000000e+00
# p14956     S             0.000000e+00
# p14957     S             0.000000e+00
# p14958     S             0.000000e+00
# p14959     S             0.000000e+00
# p15583     S             0.000000e+00
# p15568     S             0.000000e+00
# p15604     S             0.000000e+00
# p16135     S             0.000000e+00
# p16315     S             0.000000e+00
# p16316     S             0.000000e+00
# p16319     S             0.000000e+00
# p16320     S             0.000000e+00
# p16337     S             0.000000e+00
# p16350     S             0.000000e+00
# p16351     S             0.000000e+00
# p16352     S             0.000000e+00
# p16353     S             0.000000e+00
# p16354     S             0.000000e+00
# p16360     S             0.000000e+00
# p16368     S             0.000000e+00
# p16369     S             0.000000e+00
# p16370     S             0.000000e+00
# p16375     S             0.000000e+00
# p16377     S             0.000000e+00
# p16382     S             0.000000e+00
# p16402     S             0.000000e+00
# p16403     S             0.000000e+00
# p16418     S             0.000000e+00
# p16420     S             0.000000e+00
# p16423     S             0.000000e+00
# p16424     S             0.000000e+00
# p16425     S             0.000000e+00
# p16428     S             0.000000e+00
# p16432     S             0.000000e+00
# p16433     S             0.000000e+00
# p16309     S             0.000000e+00
# p16301     S             0.000000e+00
# p16295     S             0.000000e+00
# p16211     S             0.000000e+00
# p15605     S             0.000000e+00
# p16156     S             0.000000e+00
# p16167     S             0.000000e+00
# p16169     S             0.000000e+00
# p16170     S             0.000000e+00
# p16174     S             0.000000e+00
# p16175     S             0.000000e+00
# p16178     S             0.000000e+00
# p16187     S             0.000000e+00
# p16188     S             0.000000e+00
# p16192     S             0.000000e+00
# p16196     S             0.000000e+00
# p16214     S             0.000000e+00
# p16288     S             0.000000e+00
# p16225     S             0.000000e+00
# p16226     S             0.000000e+00
# p16227     S             0.000000e+00
# p16237     S             0.000000e+00
# p16243     S             0.000000e+00
# p16249     S             0.000000e+00
# p16253     S             0.000000e+00
# p16266     S             0.000000e+00
# p16272     S             0.000000e+00
# p16281     S             0.000000e+00
# p16283     S             0.000000e+00
# p16287     S             0.000000e+00
# p16434     S             0.000000e+00
# p16437     S             0.000000e+00
# p16441     S             0.000000e+00
# p16609     S             0.000000e+00
# p16571     S             0.000000e+00
# p16572     S             0.000000e+00
# p16576     S             0.000000e+00
# p16577     S             0.000000e+00
# p16578     S             0.000000e+00
# p16593     S             0.000000e+00
# p16594     S             0.000000e+00
# p16595     S             0.000000e+00
# p16596     S             0.000000e+00
# p16597     S             0.000000e+00
# p16600     S             0.000000e+00
# p16602     S             0.000000e+00
# p16610     S             0.000000e+00
# p16564     S             0.000000e+00
# p16626     S             0.000000e+00
# p16627     S             0.000000e+00
# p16633     S             0.000000e+00
# p16637     S             0.000000e+00
# p16641     S             0.000000e+00
# p16655     S             0.000000e+00
# p16659     S             0.000000e+00
# p16660     S             0.000000e+00
# p16662     S             0.000000e+00
# p16664     S             0.000000e+00
# p16671     S             0.000000e+00
# p16676     S             0.000000e+00
# p16567     S             0.000000e+00
# p16563     S             0.000000e+00
# p16448     S             0.000000e+00
# p16508     S             0.000000e+00
# p16458     S             0.000000e+00
# p16463     S             0.000000e+00
# p16467     S             0.000000e+00
# p16468     S             0.000000e+00
# p16471     S             0.000000e+00
# p16473     S             0.000000e+00
# p16474     S             0.000000e+00
# p16480     S             0.000000e+00
# p16481     S             0.000000e+00
# p16482     S             0.000000e+00
# p16485     S             0.000000e+00
# p16490     S             0.000000e+00
# p16512     S             0.000000e+00
# p16553     S             0.000000e+00
# p16523     S             0.000000e+00
# p16529     S             0.000000e+00
# p16531     S             0.000000e+00
# p16532     S             0.000000e+00
# p16538     S             0.000000e+00
# p16540     S             0.000000e+00
# p16541     S             0.000000e+00
# p16547     S             0.000000e+00
# p16548     S             0.000000e+00
# p16550     S             0.000000e+00
# p16551     S             0.000000e+00
# p16552     S             0.000000e+00
# p16136     S             0.000000e+00
# p16147     S             0.000000e+00
# p16134     S             0.000000e+00
# p15761     S             0.000000e+00
# p15771     S             0.000000e+00
# p15774     S             0.000000e+00
# p15775     S             0.000000e+00
# p15776     S             0.000000e+00
# p15787     S             0.000000e+00
# p15788     S             0.000000e+00
# p15789     S             0.000000e+00
# p15798     S             0.000000e+00
# p15799     S             0.000000e+00
# p15800     S             0.000000e+00
# p15801     S             0.000000e+00
# p15803     S             0.000000e+00
# p15809     S             0.000000e+00
# p15810     S             0.000000e+00
# p15811     S             0.000000e+00
# p15812     S             0.000000e+00
# p15813     S             0.000000e+00
# p15814     S             0.000000e+00
# p15815     S             0.000000e+00
# p15816     S             0.000000e+00
# p15823     S             0.000000e+00
# p15825     S             0.000000e+00
# p15828     S             0.000000e+00
# p15832     S             0.000000e+00
# p15856     S             0.000000e+00
# p15857     S             0.000000e+00
# p15858     S             0.000000e+00
# p15768     S             0.000000e+00
# p15757     S             0.000000e+00
# p15860     S             0.000000e+00
# p15751     S             0.000000e+00
# p15606     S             0.000000e+00
# p15610     S             0.000000e+00
# p15614     S             0.000000e+00
# p15615     S             0.000000e+00
# p15617     S             0.000000e+00
# p15622     S             0.000000e+00
# p15633     S             0.000000e+00
# p15637     S             0.000000e+00
# p15641     S             0.000000e+00
# p15643     S             0.000000e+00
# p15646     S             0.000000e+00
# p15652     S             0.000000e+00
# p15656     S             0.000000e+00
# p15667     S             0.000000e+00
# p15692     S             0.000000e+00
# p15693     S             0.000000e+00
# p15696     S             0.000000e+00
# p15708     S             0.000000e+00
# p15710     S             0.000000e+00
# p15717     S             0.000000e+00
# p15718     S             0.000000e+00
# p15725     S             0.000000e+00
# p15730     S             0.000000e+00
# p15733     S             0.000000e+00
# p15734     S             0.000000e+00
# p15745     S             0.000000e+00
# p15747     S             0.000000e+00
# p16131     S             0.000000e+00
# p15859     S             0.000000e+00
# p15864     S             0.000000e+00
# p16038     S             0.000000e+00
# p15968     S             0.000000e+00
# p15969     S             0.000000e+00
# p15983     S             0.000000e+00
# p15984     S             0.000000e+00
# p15986     S             0.000000e+00
# p15996     S             0.000000e+00
# p15999     S             0.000000e+00
# p16007     S             0.000000e+00
# p16022     S             0.000000e+00
# p16025     S             0.000000e+00
# p16030     S             0.000000e+00
# p16033     S             0.000000e+00
# p16039     S             0.000000e+00
# p15958     S             0.000000e+00
# p16045     S             0.000000e+00
# p16055     S             0.000000e+00
# p16058     S             0.000000e+00
# p16067     S             0.000000e+00
# p16072     S             0.000000e+00
# p16075     S             0.000000e+00
# p16098     S             0.000000e+00
# p16103     S             0.000000e+00
# p16106     S             0.000000e+00
# p16108     S             0.000000e+00
# p16126     S             0.000000e+00
# p16128     S             0.000000e+00
# p15865     S             0.000000e+00
# p18875     S             0.000000e+00
# p15909     S             0.000000e+00
# p15910     S             0.000000e+00
# p15867     S             0.000000e+00
# p15868     S             0.000000e+00
# p15877     S             0.000000e+00
# p15882     S             0.000000e+00
# p15883     S             0.000000e+00
# p15887     S             0.000000e+00
# p15890     S             0.000000e+00
# p15957     S             0.000000e+00
# p15895     S             0.000000e+00
# p15901     S             0.000000e+00
# p15866     S             0.000000e+00
# p15911     S             0.000000e+00
# p15913     S             0.000000e+00
# p15932     S             0.000000e+00
# p15938     S             0.000000e+00
# p15940     S             0.000000e+00
# p15944     S             0.000000e+00
# p15945     S             0.000000e+00
# p15952     S             0.000000e+00
# p15953     S             0.000000e+00
# p18148     S            -7.900000e+01
# p18147     S            -7.900000e+01
# p22252     S            -8.715000e+01
# p27665     S            -8.800000e+01
# p27651     S            -8.800000e+01
# p22926     S            -8.800000e+01
# p32295     S            -9.700000e+01
# p31622     S            -9.700000e+01
# p27659     S            -1.760000e+02
# p27658     S            -1.760000e+02
# p31410     S            -1.940000e+02
# p9623      S            -3.320000e+02
# p9624      S            -3.320000e+02

# %%
#Function to generate overview over premiumAmount per Status for specific contractID with status = 'S'
from helpers import premium_status_timeline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[29], line 2
#       1 #Function to generate overview over premiumAmount per Status for specific contractID with status = 'S'
# ----> 2 from helpers import premium_status_timeline
#
# ImportError: cannot import name 'premium_status_timeline' from 'helpers' (/Users/christianhirning/Python/Weiterbildung/Projekt/DS/helpers.py)

# %% [markdown]
# **Example 1:** negative 's' sum

# %%
#show overview for contractID with minimum cancelled sum_premiumAmount
premium_status_timeline(-1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 #show overview for contractID with minimum cancelled sum_premiumAmount
# ----> 2 premium_status_timeline(-1)
#
# NameError: name 'premium_status_timeline' is not defined

# %% [markdown]
# **here:** customer paid 3x for 2 months but got only 1x back --> we owe him 332€ --> we should keep the 'S' rows

# %%
#take closer look on contractID with highest 'S' premiumAmounts
#premium_status_timeline(0) #1.
premium_status_timeline(1) #2.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 3
#       1 #take closer look on contractID with highest 'S' premiumAmounts
#       2 #premium_status_timeline(0) #1.
# ----> 3 premium_status_timeline(1)
#
# NameError: name 'premium_status_timeline' is not defined

# %% [markdown]
# **here:** customer canceled some months first but then uncalled them again --> we got money from him --> we should keep 'S' rows again

# %% [markdown]
#  <div class="alert alert-block alert-info">
# <b>Observations:</b>
# <ol>
#     <li> Rows with status 'S' give information about paid premiums. Thus they can be more or less handeled like paid premiums.</li>
#     <li> Altough they make big percentage of all rows (~15%) their sum of premiumAmounts mainly adds up to 0 so they make pnly small percentage in change of premiumAmount (~0.1%). So they can be ignored.</li>
#     <li> Rows with status 'O' are not paid yet. And they as well only make small percentage (~0.5%). Thus they can be ignored.</li>
# </ol>
# <b>Decision:</b> We filter only paid premiums (>99% of sum of premiumAmount). Then status-columns can be dropped.
# </div>

# %% [markdown]
# #### filter & drop column

# %%
df.loc[df.status_code == 'P'].status_code.unique() # check if loc works as planned
df = df.loc[df.status_code == 'P'] # filter by status_code
df.drop(columns = ['status_code', 'status_name'], inplace=True)  # drop status_code columns
df.head() # show head of new df
# Out:
#   Indicator  BirthDate Nation  AgeAtPremium  PolicyAgeAtPremium  \
# 0         P 1956-03-12     DE            62                   1
# 1         P 1956-03-12     DE            62                   1
# 2         P 1956-03-12     DE            62                   1
# 4         P 1986-02-04     FR            32                   1
# 5         P 1986-02-04     FR            32                   2
#
#   premium_startDate premium_endDate policy_StartDate policy_EffEndDate  \
# 0        2018-08-01      2018-08-31       2017-08-01        2019-07-31
# 1        2018-10-01      2018-10-31       2017-08-01        2019-07-31
# 2        2018-11-01      2018-11-30       2017-08-01        2019-07-31
# 4        2018-03-01      2018-03-31       2016-05-01        2018-12-31
# 5        2018-06-01      2018-06-30       2016-05-01        2018-12-31
#
#    premiumAmount  FeeAmount feeRate ContractID  product_code MainProductCode  \
# 0           47.0       18.8     40%     p16174  Q055.003.000            G007
# 1           83.0       33.2     40%     p16174  Q055.001.000            G007
# 2           47.0       18.8     40%     p16174  Q055.003.000            G007
# 4           83.0       33.2     40%     p12569  Q055.001.000            G007
# 5           83.0       33.2     40%     p12569  Q055.001.000            G007
#
#   MainProductName  Deductible CmpPrivate  Model  Zone        ZoneDesc  \
# 0        Product6         0.0          I   1001  1002  Ohne USA / CAN
# 1        Product6         0.0          I   1001  1002  Ohne USA / CAN
# 2        Product6         0.0          I   1001  1002  Ohne USA / CAN
# 4        Product6         0.0          I   1001  1002  Ohne USA / CAN
# 5        Product6         0.0          I   1001  1002  Ohne USA / CAN
#
#   premium_Country premium_CountryName  product_group     product_groupName  \
# 0              NP               Nepal            102  Zusatzversicherungen
# 1              NP               Nepal            100              Produkte
# 2              NP               Nepal            102  Zusatzversicherungen
# 4              SG           Singapore            100              Produkte
# 5              SG           Singapore            100              Produkte
#
#   Nation_region premiumCountry_region premiumMonth
# 0            DE                  Asia      2018-08
# 1            DE                  Asia      2018-10
# 2            DE                  Asia      2018-11
# 4        Europe                  Asia      2018-03
# 5        Europe                  Asia      2018-06

# %% [markdown]
# ### Check behaviour of other columns

# %% [markdown]
# #### Deductible, CmpPrivate, Model, Zone, product_group
# <div class="alert alert-block alert-success">
# <b>Next:</b> Check behaviour of other columns and drop if not neaded
# <ol>
#     <li><div>
#         <input type="checkbox" id="Deductible" name="Deductible" unchecked>
#         <label for="Deductible">Deductible</label>
#     </div></li>
#     <li><div>
#         <input type="checkbox" id="CmpPrivate" name="CmpPrivate" unchecked>
#         <label for="CmpPrivate">CmpPrivate </label>
#     </div></li>
#     <li><div>
#         <input type="checkbox" id="Model, Zone" name="Model, Zone" unchecked>
#         <label for="Model, Zone">Model, Zone</label>
#     </div></li>
#     <li><div>
#         <input type="checkbox" id="product_group" name="product_group" unchecked>
#         <label for="product_group">product_group</label>
#     </div></li>
# </ol>
# </div>

# %% [markdown]
# ### Group Data

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Finally:</b> Group lines in different ways as df and plot graphically
# <ol>
#     <li> by month -->  sum premiumAmount, count ContractID & decide for other columns if necessary (This will be our df for modelling). </li>
#     <li> try different other groupings for overview (Nation_Region, ...) and explore diferences</li>
# </ol>
# </div>
